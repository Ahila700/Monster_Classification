# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('train.csv', index_col = 0)

# %%
df
# Out:
#      bone_length  rotting_flesh  hair_length  has_soul  color    type
# id
# 0       0.354512       0.350839     0.465761  0.781142  clear   Ghoul
# 1       0.575560       0.425868     0.531401  0.439899  green  Goblin
# 2       0.467875       0.354330     0.811616  0.791225  black   Ghoul
# 4       0.776652       0.508723     0.636766  0.884464  black   Ghoul
# 5       0.566117       0.875862     0.418594  0.636438  green   Ghost
# ..           ...            ...          ...       ...    ...     ...
# 886     0.458132       0.391760     0.660590  0.635689   blue  Goblin
# 889     0.331936       0.564836     0.539216  0.551471  green   Ghost
# 890     0.481640       0.501147     0.496446  0.544003  clear   Ghoul
# 896     0.294943       0.771286     0.583503  0.300618  clear   Ghost
# 897     0.670200       0.768469     0.737274  0.608384  white   Ghoul
#
# [371 rows x 6 columns]
